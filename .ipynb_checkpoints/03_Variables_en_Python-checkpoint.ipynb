# %% [markdown]
# ![03_variables.jpg](attachment:03_variables.jpg)

# %% [markdown]
# # __Variables en Python__

# %% [markdown]
# Una variable permite almacenar un valor al asignarlo a un nombre el cual puede ser utilizado para referirse al valor mas adelante en el programa.
#
# Las variables en Python se pueden crear asignando un valor a un nombre sin necesidad de declararlas antes. La asignación se realiza mediante el signo _'='_.

# %%
var1 = 123
var2 = 34.11
var3 = 'Hola Mundo'
var4 = True
# Out:
# 123
# 34.11
# Hola Mundo
# True

# %% [markdown]
# Utiliza la función _print()_ para mostrar por pantalla el valor de la variable.

# %%
print(var1)
print(var2)
print(var3)
print(var4)
# Out:
# 123
# 34.11
# Hola Mundo
# True

# %% [markdown]
# _Se declaran, luego se definen.._

# %%
# declarar   definir
nombre = 'Pedro Pedrito'
print(nombre)
# Out:
# Pedro Pedrito

# %% [markdown]
# _Son modificables.._

# %%
nombre = 'Jose'
nombre = 'Betania'
nombre = 'Guillermo'
print(nombre)
# Out:
# Guillermo

# %% [markdown]
# _Son operables.._

# %%
num = 10
num += 5
print(num)
# Out:
# 15

# %% [markdown]
# _Se concatenan.._

# %%
nombre = 'Miguel'
bienvenida = 'Hola '+ nombre + '. Bienvenido!'
print(bienvenida)
# Out:
# Hola Miguel. Bienvenido!

# %% [markdown]
# _Se pueden asignar multiples variables en la misma linea.._

# %%
x, y, z = 2, 4, 6
print(x, y, z)
# Out:
# 2 4 6

# %% [markdown]
# ### _Concatenación f-string_

# %% [markdown]
# Convierte cualquier dato a tipo texto.

# %%
nombre = 'Gaby'
bienvenida = f'Hola {nombre}. Bienvenida!'
print(bienvenida)
# Out:
# Hola Gaby. Bienvenida!

# %% [markdown]
# ### _Borrar contenido de la variable_

# %% [markdown]
# Se utiliza el comando _del_ y al hacerlo, la variable declarada queda sin valor arrojando un error.

# %%
nombre = 'Jesus'
del nombre
print(nombre)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 3>()
#       1 nombre = 'Jesus'
#       2 del nombre
# ----> 3 print(nombre)
#
# NameError: name 'nombre' is not defined

# %% [markdown]
# ### *Operador de pertenencia*

# %% [markdown]
# Busca una variable dentro de otra y devuelve un booleano.

# %%
nombre = 'Gaby'
bienvenida = f'Hola {nombre}. Bienvenida!'
print(bienvenida)

# buscar secuencia 'ola' en la variable bienvenida
print('ola' in bienvenida)

# buscar Gaby en la variable 'bienvenida'
print('Gaby' in bienvenida)
# Out:
# Hola Gaby. Bienvenida!
# True
# True

# %% [markdown]
# ### *Desempaquetado*

# %% [markdown]
# Consiste en asignarle valores contenidos en un array a varias variables. Funciona sólo cuando la cantidad de valores es igual a la cantidad de variables.

# %%
# declaramos un tipo de dato conocido como tupla
datos = ('cilantro', 'cebolla')
verdura_1, verdura_2 = datos
print(verdura_1)
print(verdura_2)
# Out:
# cilantro
# cebolla

# %% [markdown]
# # __Nombres de Variables__

# %% [markdown]
# Podemos asignar el nombre que queramos, respetando no usar las palabras reservadas de Python ni espacio, guiones o números al principio.
#
# Es importante tener en cuenta que las variables adoptan la naturaleza del tipo de datos que se almacena en ellas.

# %%
# nombres de variables validos
_variable = 'Variable válida'
vari_able = 12
variable20 = 20
variable = True
variaBLe = 54.1

# %%
# nombres de variables no validos
2variable = 'Variable no valida'
var-iable = 112
var iable = False
# Out:
#   Input In [16]
#     2variable = 'Variable no valida'
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### _Palabras reservadas de Python_

# %% [markdown]
# Son utilizadas por Python internamente, por lo que no podemos usarlas para nombrar variables o funciones. Conozcámos cuáles son:

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', '__peg_parser__', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ### _Estilos de Variables_

# %% [markdown]
# A la hora de definir el nombre de las variables existen diferentes estilos según el PEP8 de Python <a href="https://www.python.org/dev/peps/pep-0008/#naming-conventions" target="_blank">Link</a>
#
# * $b$: una sola letra minúscula.
#
# * $B$: una sola letra mayúscula
#
# * $lowercase$: todas minúsculas.
#
# * $lower\_case\_with\_underscores$: todas minúsculas separadas por piso. Conocida como snakecase.
#
# * $UPPERCASE$: todas mayúsculas.
#
# * $UPPER\_CASE\_WITH\_UNDERSCORES$: Todas mayúsculas separadas por piso.
#
# * $CapitalizedWords$: También llamadas CapWords o CamelCase. Letra inicial de la palabra en mayúscula, las demás en minúscula.
#
# * $mixedCase$: Se diferencia de CamelCase en que la letra de la primera palabra es minúscula.
#
# * $Capitalized\_Words\_With\_Underscores$: Estilo poco estético.
#
# * Nota: Cuando utilice acrónimos en CamelCase, escriba todas las letras del acrónimo en mayúscula (HTTPServer).
#
# El estilo mas recomendado por los desarrolladores es _snakecase_ aunque no es una regla definitiva. Puedes usar el estilo de tu preferencia. En lo que sigue, veamos un ejemplo de cada estilo.

# %%
# lowercase
variable = 'Hola mundo'
# uppercase
VARIABLE = 'Constante'
# lowercase with underscores
variable_minusculas_con_guion_bajo = 123
# uppercase with underscores
VARIABLES_MAYUSCULAS_CON_GUION_BAJO = 456
# CamelCase
VariableName = 'CapWords o CamelCase'
# mixedCase
nombreVariable = 'mixedCase style'

# %% [markdown]
# # __Tipo de Dato de la Variable__

# %% [markdown]
# Podemos conocer el tipo de dato de una variable con la función _type()_ de python

# %%
a = 123
type(a)
# Out:
# int

# %%
b = 'Hola mundo!!!'
type(b)
# Out:
# str

# %%
c = False
type(c)
# Out:
# bool

# %% [markdown]
# # __Alcance de las Variables__

# %% [markdown]
# Cuando definimos una variable es importante conocer el alcance o _scope_ que tiene, es decir, el uso de la variable en una o diferentes áreas del código.
#
# Veamos el siguiente ejemplo: Al inicio la variable x se asigna con valor 10 y tiene un alcance global. Por otro lado, la variable x declarada con valor 5 dentro de la función tiene un alcance local. Esto significa que cuando hacemos _print(x)_ estamos accediendo a la variable global x y no a la x definida dentro de la función.

# %%
x = 10

def funcion():
    x = 5

print(x)
# Out:
# 10

# %% [markdown]
# Mas adelante, en un futuro notebooks vamos a profundizar mas sobre este tema!
