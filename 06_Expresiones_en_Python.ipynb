# %% [markdown]
# ![06_Expresiones.jpg](attachment:06_Expresiones.jpg)

# %% [markdown]
# # **Expresiones en Python**

# %% [markdown]
# ## Clasificación

# %% [markdown]
# Se clasifican según el tipo de dato y los operadores que utilizan.
#
# - $\text{Aritméticas}$: Análogas a fórmulas matemáticas, en donde se utilizan operadores aritméticos ($\ +\ ,\ -\ ,\ *\ ,\ /\ ,\ **\ ,\ \%\ ,\ //\ $), variables y constantes numéricas. Ejemplo:
#
# <br><br>
#
# - $\text{Expresión algebraica}$:
#
# $$-8 * 2 + \frac{4}{2}* \pi *\sqrt(x)$$
# <br><br>
#
# - $\text{Alfanuméricas}$: Se utilizan operadores alfanuméricos como la **concatenación** y producen resultados de tipo alfanuméricos. Ejemplo: "Ing.\ " + "Jorge\ López"\ =\ "Ing.\ Jorge\ López"
#
# <br><br>
#
# - $\text{Relacionales}$: Se utilizan operadores relacionales ($<\ ,\ >\ ,\ <=\ ,\ >=\ ,\ ==\ ,\ !=$). Con estos operadores se compara entre dos valores del mismo tipo, es decir que los operandos son ambos numéricos, ambos caracter o ambos de tipo lógico. El resultado de la evaluación de una expresión relacional es de tipo lógico, $True$ o $False$. Ejemplo:
#
# $$A + B < = A * B$$
#
# <br><br>
#
# - $\text{Lógicas}$: Se utilizan operadores lógicos ($and\ ,\ or\ y\ not$). El resultado de este tipo de expresión es un valor lógico, $True$ o $False$, el cual se deduce de analizar la tabla de verdad correspondiente a los conectores lógicos.

# %% [markdown]
# ![tabla_de_verdad2.png](data:image/png;base64,...)

# %% [markdown]
# ## Ejemplo de uso

# %% [markdown]
# El promedio de las edades de los hombre la base de datos es 35 y el de las mujeres es 38. Usar un operador relacional para determinar si el promedio de las edades de los hombre es mayor o menor que el promedio de las mujeres.

# %%
promedio_hombres = 35
promedio_mujeres = 38
promedio_hombres > promedio_mujeres
# Out:
# False

# %% [markdown]
# ## Precedencia de operadores

# %% [markdown]
# Hace referencia a la prioridad entre operadores. Si no tengo signos de agrupación, ¿Qué opero primero?
#
# La siguiente piramide muestra la prioridad que sigue Python de acuerdo a los operadores que contenga la expresión. Va de mayor prioridad en la parte mas alta de la piramide hasta los de menor prioridad en la base.

# %% [markdown]
# ![precedencia_operadores2.png](data:image/png;base64,...)

# %%
(10/5) ** 4 > 15 and (8 + 4) == 12
# 2   ** 4 > 15 and 12       == 12
#     16   > 15 and     12   == 12
#       True    and    True
#              True
# Out:
# True

# %% [markdown]
# # **Ejercicios**

# %% [markdown]
# ### Ejercicio 1:
# Diseñe un algoritmo que permita calcular el promedio de los errores que comete el algoritmo de Inteligencia Artificial en el tarea de predicción. Los resultados de error son cinco y el usuario los ingresa por teclado. Para terminar, el algoritmo deberá mostras el aviso de: _"El error promedio es: ###"_

# %%
e1 = float(input('Error 1: '))
e2 = float(input('Error 2: '))
e3 = float(input('Error 3: '))
e4 = float(input('Error 4: '))
e5 = float(input('Error 5: '))

prom = (e1 + e2 + e3 + e4 + e5)/5

print('El error promedio es:', prom)
print('El error promedio es: {}'.format(prom))
print(f'El error promedio es: {prom}')
# Out:
# Error 1: 12
# Error 2: 12
# Error 3: 32
# Error 4: 21
# Error 5: 21
# El error promedio es: 19.6
# El error promedio es: 19.6
# El error promedio es: 19.6

# %% [markdown]
# ### Ejercicio 2:
# Escriba un programa que solicite al usuario que ingrese la base y la altura del triángulo y calcule el área de este triángulo (área $= 0.5 \cdot b \cdot h$).

# %%
base = float(input('Base del triangulo: '))
altura = float(input('Altura del triangulo: '))

area = 0.5 * base * altura
print(f'El area del triangulo es: {area}')
# Out:
# El area del triangulo es: 3.1799999999999997

# %% [markdown]
# ### Ejercicio 3
# Escriba un script que solicite al usuario que ingrese el lado a, el lado b y el lado c del triángulo. Calcula el perímetro del triángulo (perímetro $= a + b + c$).

# %%
lado_a = float(input('Lado A: '))
lado_b = float(input('Lado B: '))
lado_c = float(input('Lado C: '))

print(f'El perimetro del triangulo es de : {lado_a + lado_b + lado_c}')
# Out:
# El perimetro del triangulo es de : 12.15

# %% [markdown]
# ### Ejercicio 4:
#
# Calcula el área ($area = largo \cdot ancho$) y perímetro de un rectangulo ($perimetro = 2 \cdot (largo + ancho)$)

# %%
longitud = float(input('Largo del rectangulo: '))
altura = float(input('Alto del rectangulo: '))

area = longitud * altura
perimetro = 2 * (longitud + altura)
print(f'Area del rectangulo: {area}, Perimetro del rectangulo: {perimetro}')
# Out:
# Area del rectangulo: 29.52, Perimetro del rectangulo: 29.400000000000002

# %% [markdown]
# ### Ejercicio 5
# Calcule la pendiente, la intersección x y la intersección y de $y = 2x -2$

# %%
pendiente = 2
inter_Y = -2
inter_X = 1
print(f'Prendiente: {pendiente} \nInterseccion con en el eje X: {inter_X} \nInterseccion con el eje Y: {inter_Y}')
# Out:
# Prendiente: 2
# Interseccion con en el eje X: 1
# Interseccion con el eje Y: -2

# %% [markdown]
# ### Ejercicio 6
#
# Encuentra la pendiente y la distancia euclideana entre los puntos ($2,2$) y ($6,10$)

# %%
# pendiente = (y2 - y1)/(x2 - x1)
slope = (10 - 2)/(6 - 2)

# distancia euclidiana = ((x2 - x1)**2 + (y2 - y1)**2)**0.5
distance = ((6 - 2)**2 + (10 - 2)**2)**0.5

print(f'Pendiente: {slope}, Distancia: {distance}')
# Out:
# Pendiente: 2.0, Distancia: 8.94427190999916

# %% [markdown]
# ### Ejercicio 7
#
# Compare las pendientes de los ejercicios previos

# %%
print(f'Pendiente Ejercicio 5: {pendiente} \nPendiente Ejercicio 6: {slope}')
print('Ambas pendientes son iguales!')
# Out:
# Pendiente Ejercicio 5: 2
# Pendiente Ejercicio 6: 2.0
# Ambas pendientes son iguales!

# %% [markdown]
# ### Ejercicio 8
#
# Encuentre la longitud de 'Python' y 'Dragon' y comparelas

# %%
print(f'Longitud Python: ',len('Python'))
print(f'Longitud dragon: ',len('dragon'))
print(len('Python') == len('dragon'))
# Out:
# Longitud Python:  6
# Longitud dragon:  6
# True

# %% [markdown]
# ### Ejercicio 9
#
# Use un operador para chequear si la palabra 'on' se encuentra en las palabras Python y Dragon

# %%
print('on' in 'Puthon')
print('on' in 'Dragon')
# Out:
# True
# True

# %% [markdown]
# ### Ejercicio 10
#
# Verifique que la palabra 'on' este en Python y Dragon

# %%
a = 'on'
b = 'python'
c = 'dragon'
print((a in b) and (a in c))
# Out:
# True

# %% [markdown]
# ### Ejercicio 11
#
# Encuentra la longitud de la palabra 'Python' y convierte dicho valor en un float y luego en un string todo en un mismo paso

# %%
print(str(float(len('Python'))))
# Out:
# 6.0

# %% [markdown]
# ### Ejercicio 12
#
# Chequea si un numero es par o impar

# %%
num = int(input('Ingrese un numero entero: '))

if num%2 == 0:
    print(f'{num} es par')
else:
    print(f'{num} es impar')
# Out:
# 7 es impar

# %% [markdown]
# ### Ejercicio 13
#
# Verifique que 9.8 convertido en entero es igual a 10

# %%
print(int(9.8) == 10)
# Out:
# False

# %% [markdown]
# ### Ejercicio 14
#
# Escriba un programa que solicite la edad del usuario y devuelva el numero de segundos que ha vivido

# %%
year = int(input('Ingrese edad: '))
print(f'El numero de segundos vividos es de: {year*365*24*60*60}')
# Out:
# El numero de segundos vividos es de: 946080000

# %% [markdown]
# ### Ejercicio 15
# Resuelva la siguiente operacion

# %%
a, b, c, d = 1, 2, 3, 4
a + (b - c * (d - (a + b) * (c - c / d * a) % a + b * c) - (b ** c)) ** b
# Out:
# 1140.0625

# %% [markdown]
# ### Ejercicio 16
#
# Escriba la siguiente expresion algebraica en Python
#
# ![image.png](attachment:image.png)

# %%
a, b, c, d = 1, 2, 3, 4
((a +((b-c)/d-a)-(c/d))/(a+b)) - ((c/(d+a)) + (b**c)**a)/((d+1)/3+a)
# Out:
# -3.558333333333333
